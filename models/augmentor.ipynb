# %%
import Augmentor

# %%
p = Augmentor.Pipeline("Augmentation")
# Out:
# c:\Users\visha\skin-cancer\venv\Lib\site-packages\Augmentor\Pipeline.py:1086: SyntaxWarning: invalid escape sequence '\B'
#   """
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 p = Augmentor.Pipeline("Augmentation")
#
# File c:\Users\visha\skin-cancer\venv\Lib\site-packages\Augmentor\Pipeline.py:87, in Pipeline.__init__(self, source_directory, output_directory, save_format)
#      84 self.process_ground_truth_images = False
#      86 if source_directory is not None:
# ---> 87     self._populate(source_directory=source_directory,
#      88                    output_directory=output_directory,
#      89                    ground_truth_directory=None,
#      90                    ground_truth_output_directory=output_directory)
#
# File c:\Users\visha\skin-cancer\venv\Lib\site-packages\Augmentor\Pipeline.py:135, in Pipeline._populate(self, source_directory, output_directory, ground_truth_directory, ground_truth_output_directory)
#     133 # Check if the source directory for the original images to augment exists at all
#     134 if not os.path.exists(source_directory):
# --> 135     raise IOError("The source directory you specified does not exist.")
#     137 # If a ground truth directory is being specified we will check here if the path exists at all.
#     138 if ground_truth_directory:
#
# OSError: The source directory you specified does not exist.

# %%
p.random_distortion(probability=0.4, grid_height=4, grid_width=4, magnitude=1)

# %%
p.process()
# Out:
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x205E02CC560>: 100%|██████████| 1621/1621 [00:04<00:00, 358.88 Samples/s]
